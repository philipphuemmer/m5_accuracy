# %% [markdown]
# ## Please input your directory for the top level folder
# folder name : SUBMISSION MODEL

# %%
dir_ = 'E:/Seminararbeit/Code/A1/' # input only here

# %% [markdown]
# #### setting other directory

# %%
raw_data_dir = dir_+'2. data/'
processed_data_dir = dir_+'2. data/processed/'
log_dir = dir_+'4. logs/'
model_dir = dir_+'5. models/'

# %%
####################################################################################
########################### 1-1. recursive model by store ##########################
####################################################################################

# %%
ver, KKK = 'priv', 0
STORES_IDS = ['WI_3'] #'CA_1','CA_2','CA_3','CA_4','TX_1','TX_2', 'TX_3','WI_1','WI_2',

# %%
import numpy as np
import pandas as pd
import os, sys, gc, time, warnings, pickle, psutil, random

from multiprocessing import Pool

warnings.filterwarnings('ignore')

# %%
########################### Helpers
#################################################################################
## Seeder
def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)

    
## Multiprocess Runs
def df_parallelize_run(func, t_split):
    num_cores = np.min([N_CORES,len(t_split)])
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, t_split), axis=1)
    pool.close()
    pool.join()
    return df

# %%
########################### Helper to load data by store ID
#################################################################################
# Read data
def get_data_by_store(store):
    
    # Read and contact basic feature
    df = pd.concat([pd.read_pickle(BASE),
                    pd.read_pickle(PRICE).iloc[:,2:],
                    pd.read_pickle(CALENDAR).iloc[:,2:]],
                    axis=1)
    
    df = df[df['d']>=START_TRAIN]
    
    df = df[df['store_id']==store]

    df2 = pd.read_pickle(MEAN_ENC)[mean_features]
    df2 = df2[df2.index.isin(df.index)]
    
    df3 = pd.read_pickle(LAGS).iloc[:,3:]
    df3 = df3[df3.index.isin(df.index)]
    
    df = pd.concat([df, df2], axis=1)
    del df2
    
    df = pd.concat([df, df3], axis=1)
    del df3

    features = [col for col in list(df) if col not in remove_features]
    df = df[['id','d',TARGET]+features]
    
    df = df.reset_index(drop=True)
    
    return df, features

# Recombine Test set after training
def get_base_test():
    base_test = pd.DataFrame()

    for store_id in STORES_IDS:
        temp_df = pd.read_pickle(processed_data_dir+'test_'+store_id+'.pkl')
        temp_df['store_id'] = store_id
        base_test = pd.concat([base_test, temp_df]).reset_index(drop=True)
    
    return base_test


########################### Helper to make dynamic rolling lags
#################################################################################
def make_lag(LAG_DAY):
    lag_df = base_test[['id','d',TARGET]]
    col_name = 'sales_lag_'+str(LAG_DAY)
    lag_df[col_name] = lag_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(LAG_DAY)).astype(np.float16)
    return lag_df[[col_name]]


def make_lag_roll(LAG_DAY):
    shift_day = LAG_DAY[0]
    roll_wind = LAG_DAY[1]
    lag_df = base_test[['id','d',TARGET]]
    col_name = 'rolling_mean_tmp_'+str(shift_day)+'_'+str(roll_wind)
    lag_df[col_name] = lag_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(shift_day).rolling(roll_wind).mean())
    return lag_df[[col_name]]

# %%
########################### Model params
#################################################################################
import lightgbm as lgb
lgb_params = {
                    'boosting_type': 'gbdt',
                    'objective': 'tweedie',
                    'tweedie_variance_power': 1.1,
                    'metric': 'rmse',
                    'subsample': 0.5,
                    'subsample_freq': 1,
                    'learning_rate': 0.015,
                    'num_leaves': 2**11-1,
                    'min_data_in_leaf': 2**12-1,
                    'feature_fraction': 0.5,
                    'max_bin': 100,
                    'n_estimators': 3000,
                    'boost_from_average': False,
                    'verbose': 1,
                    'n_jobs': 1
                }

# %%
########################### Vars
#################################################################################
VER = 1                          
SEED = 42                        
seed_everything(SEED)            
lgb_params['seed'] = SEED        
N_CORES = psutil.cpu_count()     


#LIMITS and const
TARGET      = 'sales'            
START_TRAIN = 0                  
END_TRAIN   = 1941 - 28*KKK      
P_HORIZON   = 28                 
USE_AUX     = False             

remove_features = ['id','state_id','store_id',
                   'date','wm_yr_wk','d',TARGET]
mean_features   = ['enc_cat_id_mean','enc_cat_id_std',
                   'enc_dept_id_mean','enc_dept_id_std',
                   'enc_item_id_mean','enc_item_id_std'] 

ORIGINAL = raw_data_dir
BASE     = processed_data_dir+'processedgrid_part_1.pkl'
PRICE    = processed_data_dir+'processedgrid_part_2.pkl'
CALENDAR = processed_data_dir+'processedgrid_part_3.pkl'
LAGS     = processed_data_dir+'processedlags_df_28.pkl'
MEAN_ENC = processed_data_dir+'processedmean_encoding_df.pkl'


#SPLITS for lags creation
SHIFT_DAY  = 28
N_LAGS     = 15
LAGS_SPLIT = [col for col in range(SHIFT_DAY,SHIFT_DAY+N_LAGS)]
ROLS_SPLIT = []
for i in [1,7,14]:
    for j in [7,14,30,60]:
        ROLS_SPLIT.append([i,j])

# %%
########################### Train Models
#################################################################################
for store_id in STORES_IDS:
    print('Train', store_id)
    
    grid_df, features_columns = get_data_by_store(store_id)
    
    train_mask = grid_df['d']<=END_TRAIN
    valid_mask = train_mask&(grid_df['d']>(END_TRAIN-P_HORIZON))
    preds_mask = (grid_df['d']>(END_TRAIN-100)) & (grid_df['d'] <= END_TRAIN+P_HORIZON)
    
    train_data = lgb.Dataset(grid_df[train_mask][features_columns], 
                       label=grid_df[train_mask][TARGET])
    
    valid_data = lgb.Dataset(grid_df[valid_mask][features_columns], 
                       label=grid_df[valid_mask][TARGET])
    
    grid_df = grid_df[preds_mask].reset_index(drop=True)
    keep_cols = [col for col in list(grid_df) if '_tmp_' not in col]
    grid_df = grid_df[keep_cols]
    
    d_sales = grid_df[['d','sales']]
    substitute = d_sales['sales'].values
    substitute[(d_sales['d'] > END_TRAIN)] = np.nan
    grid_df['sales'] = substitute
    
    grid_df.to_pickle(processed_data_dir+'test_'+store_id+'.pkl')
    del grid_df, d_sales, substitute
    

    seed_everything(SEED)
    estimator = lgb.train(lgb_params,
                          train_data,
                          valid_sets = [valid_data],
                          callbacks=[lgb.log_evaluation(1, True)]
                          )
    
    display(pd.DataFrame({'name':estimator.feature_name(),
                          'imp':estimator.feature_importance()}).sort_values('imp',ascending=False).head(25))

    
    model_name = model_dir+'lgb_model_'+store_id+'_v'+str(VER)+'.bin'
    pickle.dump(estimator, open(model_name, 'wb'))

    del train_data, valid_data, estimator
    gc.collect()
    
    MODEL_FEATURES = features_columns
# Out:
# Train WI_3
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 3.892697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8141
# [LightGBM] [Info] Number of data points in the train set: 4772041, number of used features: 72
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's rmse: 3.80963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's rmse: 3.79431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's rmse: 3.7783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's rmse: 3.76167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's rmse: 3.74464
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's rmse: 3.72691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's rmse: 3.70872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's rmse: 3.68985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's rmse: 1.85891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's rmse: 1.8588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's rmse: 1.85853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's rmse: 1.85847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's rmse: 1.85829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's rmse: 1.85813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's rmse: 1.85806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's rmse: 1.85795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's rmse: 1.85793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's rmse: 1.85765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's rmse: 1.85762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's rmse: 1.85741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's rmse: 1.8573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's rmse: 1.8572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's rmse: 1.85726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's rmse: 1.85698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's rmse: 1.85699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's rmse: 1.85701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's rmse: 1.85688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's rmse: 1.8567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's rmse: 1.85668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's rmse: 1.85661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's rmse: 1.85649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's rmse: 1.8565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's rmse: 1.85632
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's rmse: 1.85603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's rmse: 1.85599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's rmse: 1.85583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's rmse: 1.85567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's rmse: 1.85555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's rmse: 1.85535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's rmse: 1.85541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's rmse: 1.85531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's rmse: 1.8552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's rmse: 1.8549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's rmse: 1.85486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's rmse: 1.8548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's rmse: 1.85465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's rmse: 1.85457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's rmse: 1.85449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	valid_0's rmse: 1.85442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's rmse: 1.85444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [415]	valid_0's rmse: 1.85442
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's rmse: 1.85398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	valid_0's rmse: 1.85399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	valid_0's rmse: 1.85393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's rmse: 1.85382
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's rmse: 1.85376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's rmse: 1.85363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's rmse: 1.85349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's rmse: 1.85334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's rmse: 1.85325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's rmse: 1.85313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's rmse: 1.85309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	valid_0's rmse: 1.85303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's rmse: 1.85302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [429]	valid_0's rmse: 1.85294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [430]	valid_0's rmse: 1.85274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's rmse: 1.85261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [432]	valid_0's rmse: 1.85254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	valid_0's rmse: 1.85252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's rmse: 1.85211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [435]	valid_0's rmse: 1.85202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [436]	valid_0's rmse: 1.85197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	valid_0's rmse: 1.85165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [438]	valid_0's rmse: 1.85152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's rmse: 1.85142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	valid_0's rmse: 1.85136
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	valid_0's rmse: 1.85127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [442]	valid_0's rmse: 1.85119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [443]	valid_0's rmse: 1.85113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's rmse: 1.8509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [445]	valid_0's rmse: 1.85088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's rmse: 1.85065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	valid_0's rmse: 1.85055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [448]	valid_0's rmse: 1.85049
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [449]	valid_0's rmse: 1.85047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	valid_0's rmse: 1.85032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [451]	valid_0's rmse: 1.85019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	valid_0's rmse: 1.8501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	valid_0's rmse: 1.85001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
#
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2939]	valid_0's rmse: 1.76271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2940]	valid_0's rmse: 1.76265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2941]	valid_0's rmse: 1.76261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2942]	valid_0's rmse: 1.76261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2943]	valid_0's rmse: 1.76263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2944]	valid_0's rmse: 1.76259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2945]	valid_0's rmse: 1.76265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2946]	valid_0's rmse: 1.76262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2947]	valid_0's rmse: 1.76259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2948]	valid_0's rmse: 1.76255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2949]	valid_0's rmse: 1.76252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2950]	valid_0's rmse: 1.76239
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2951]	valid_0's rmse: 1.76241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2952]	valid_0's rmse: 1.76241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2953]	valid_0's rmse: 1.76238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2954]	valid_0's rmse: 1.76233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2955]	valid_0's rmse: 1.76223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2956]	valid_0's rmse: 1.76219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2957]	valid_0's rmse: 1.76211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2958]	valid_0's rmse: 1.76214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2959]	valid_0's rmse: 1.76214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2960]	valid_0's rmse: 1.76214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2961]	valid_0's rmse: 1.76211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2962]	valid_0's rmse: 1.76201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2963]	valid_0's rmse: 1.76201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2964]	valid_0's rmse: 1.76198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2965]	valid_0's rmse: 1.762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2966]	valid_0's rmse: 1.76197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2967]	valid_0's rmse: 1.76195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2968]	valid_0's rmse: 1.76194
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2969]	valid_0's rmse: 1.76191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2970]	valid_0's rmse: 1.76192
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2971]	valid_0's rmse: 1.76195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2972]	valid_0's rmse: 1.76202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2973]	valid_0's rmse: 1.76196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2974]	valid_0's rmse: 1.76201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2975]	valid_0's rmse: 1.76196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2976]	valid_0's rmse: 1.76193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2977]	valid_0's rmse: 1.76199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2978]	valid_0's rmse: 1.7619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2979]	valid_0's rmse: 1.76182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2980]	valid_0's rmse: 1.76173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2981]	valid_0's rmse: 1.76173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2982]	valid_0's rmse: 1.76164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2983]	valid_0's rmse: 1.7616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2984]	valid_0's rmse: 1.7615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2985]	valid_0's rmse: 1.76148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2986]	valid_0's rmse: 1.76139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2987]	valid_0's rmse: 1.76138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2988]	valid_0's rmse: 1.76142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2989]	valid_0's rmse: 1.76145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2990]	valid_0's rmse: 1.76143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2991]	valid_0's rmse: 1.76132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2992]	valid_0's rmse: 1.76129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2993]	valid_0's rmse: 1.7612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2994]	valid_0's rmse: 1.76119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2995]	valid_0's rmse: 1.76116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2996]	valid_0's rmse: 1.76114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2997]	valid_0's rmse: 1.76112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2998]	valid_0's rmse: 1.76112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2999]	valid_0's rmse: 1.76099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3000]	valid_0's rmse: 1.76099
#                       name    imp
# 59         rolling_std_180  49914
# 23                    tm_w  49601
# 58        rolling_mean_180  49046
# 22                    tm_d  48008
# 34         enc_item_id_std  42464
# 33        enc_item_id_mean  42182
# 7                price_std  40992
# 11            item_nunique  40041
# 57          rolling_std_60  38104
# 6                price_min  35585
# 60    rolling_mean_tmp_1_7  33992
# 56         rolling_mean_60  33764
# 55          rolling_std_30  32998
# 13        price_momentum_m  32450
# 1                  dept_id  31463
# 8               price_mean  30027
# 61   rolling_mean_tmp_1_14  29754
# 4               sell_price  29754
# 27                   tm_dw  28711
# 5                price_max  28689
# 3                  release  28399
# 53          rolling_std_14  28019
# 71  rolling_mean_tmp_14_60  27084
# 64    rolling_mean_tmp_7_7  25771
# 62   rolling_mean_tmp_1_30  25655
